# %%
# Crie uma lista vazia para armazenar as tarefas
tarefas = []

# Função para adicionar uma tarefa
def adicionar_tarefa():
    tarefa = input("Digite a tarefa que deseja adicionar: ")
    tarefas.append(tarefa)
    print("Tarefa adicionada com sucesso!")

# Função para listar as tarefas
def listar_tarefas():
    if not tarefas:
        print("Não há tarefas na lista.")
    else:
        print("Lista de Tarefas:")
        for i, tarefa in enumerate(tarefas, 1):
            print(f"{i}. {tarefa}")

# Função para marcar uma tarefa como concluída
def marcar_concluida():
    listar_tarefas()
    if tarefas:
        try:
            numero = int(input("Digite o número da tarefa concluída: "))
            if 1 <= numero <= len(tarefas):
                tarefas.pop(numero - 1)
                print("Tarefa marcada como concluída!")
            else:
                print("Número inválido.")
        except ValueError:
            print("Digite um número válido.")

# Loop principal do programa
while True:
    print("\nEscolha uma opção:")
    print("1. Adicionar Tarefa")
    print("2. Listar Tarefas")
    print("3. Marcar Tarefa como Concluída")
    print("4. Sair")
    
    opcao = input("Digite o número da opção desejada: ")

    if opcao == "1":
        adicionar_tarefa()
    elif opcao == "2":
        listar_tarefas()
    elif opcao == "3":
        marcar_concluida()
    elif opcao == "4":
        print("Saindo do gerenciador de tarefas. Até logo!")
        break
    else:
        print("Opção inválida. Por favor, escolha uma opção válida.")
# Out:
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 1
# Digite a tarefa que deseja adicionar: Exercícios Estatística
# Tarefa adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 1
# Digite a tarefa que deseja adicionar: Arrumar Bike
# Tarefa adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 1
# Digite a tarefa que deseja adicionar: Comprar presente de dia das crianças
# Tarefa adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 1
# Digite a tarefa que deseja adicionar: Reservar restaurante para o meu aniversário
# Tarefa adicionada com sucesso!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 2
# Lista de Tarefas:
# 1. Exercícios Estatística
# 2. Arrumar Bike
# 3. Comprar presente de dia das crianças
# 4. Reservar restaurante para o meu aniversário
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 3
# Lista de Tarefas:
# 1. Exercícios Estatística
# 2. Arrumar Bike
# 3. Comprar presente de dia das crianças
# 4. Reservar restaurante para o meu aniversário
# Digite o número da tarefa concluída: 2
# Tarefa marcada como concluída!
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 2
# Lista de Tarefas:
# 1. Exercícios Estatística
# 2. Comprar presente de dia das crianças
# 3. Reservar restaurante para o meu aniversário
#
# Escolha uma opção:
# 1. Adicionar Tarefa
# 2. Listar Tarefas
# 3. Marcar Tarefa como Concluída
# 4. Sair
# Digite o número da opção desejada: 4
# Saindo do gerenciador de tarefas. Até logo!
